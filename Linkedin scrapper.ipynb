# %% [markdown]
# <font size="6">**Linkedin Scrapper**</font>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

from time import sleep

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['EMAIL'], os.environ['PASSWORD']
# Out:
# ('ruizdavalos@gmail.com', 'juan4669')

# %%
driver = webdriver.Chrome()

# %%
driver.title
# Out:
# ''

# %%
driver.get('https://www.linkedin.com/login')

# %%
driver.title
# Out:
# 'LinkedIn Login, Sign in | LinkedIn'

# %%
email= driver.find_element(By.ID,'username')
email.send_keys(os.environ['EMAIL'])

password= driver.find_element(By.ID,'password')
password.send_keys(os.environ['PASSWORD'])

password.submit()

# %%
url="https://www.linkedin.com/in/juan--ruiz/"
driver.get(url)

# %%
profile_data={}

# %%
driver.title
# Out:
# '(18) Juan Ruiz | LinkedIn'

# %%
page_source = driver.page_source
soup = BeautifulSoup(page_source,'lxml')

# %%
name = soup.find('h1', {'class':'TJvZKwEBLuBIvRUZGamLzDCMNpOEUKZs inline t-24 v-align-middle break-words'})
name = name.get_text().strip()

profile_data['name']= name
profile_data['url']=url

# %%
headline= soup.find('div', {'class':'text-body-medium break-words'})

headline=headline.get_text().strip()

profile_data['headline']=headline

# %% [markdown]
# ### Show More

# %%
driver.find_element(By.CLASS_NAME,'inline-show-more-text__button').click()

# %%
page_source = driver.page_source
#soup= BeautifulSoup(page_source='lxml')

about = soup.find('div', {'class':'display-flex ph5 pv3'})

about = about.get_text().strip()

profile_data['about'] = about

# %%
profile_data
# Out:
# {'name': 'Juan Ruiz',
#  'url': 'https://www.linkedin.com/in/juan--ruiz/',
#  'headline': 'Ingeniero Industrial | Python | Data science | Data analytics | Business Intelligence | Power BI | SQL | Tableau',
#  'about': 'Confió plenamente en mis habilidades blandas para liderar y crear equipos de trabajos sólidos, basándome en la participación y escucha activa de todos los colaboradores.Así como confesar ser un apasionado en la búsqueda de resolución de problemas, lo cual implica tener siempre una gran motivación para seguir perfeccionando habilidades que a futuro permitan desarrollar ideas/soluciones sólidas y duraderas.Confió plenamente en mis habilidades blandas para liderar y crear equipos de trabajos sólidos, basándome en la participación y escucha activa de todos los colaboradores.\n\nAsí como confesar ser un apasionado en la búsqueda de resolución de problemas, lo cual implica tener siempre una gran motivación para seguir perfeccionando habilidades que a futuro permitan desarrollar ideas/soluciones sólidas y duraderas.'}

# %% [markdown]
# ### Read Experience

# %%
page_source= driver.page_source

sections= soup.find_all('section',{'class':'artdeco-card pv-profile-card break-words mt2'})

sections
# Out:
# [<section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="guidance">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-large">
#  <span aria-hidden="true"><!-- -->Sugerencias<!-- --></span><span class="visually-hidden"><!-- -->Sugerencias<!-- --></span>
#  </h2>
#  <!-- --> <p class="pvs-header__metadata text-body-small">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><li-icon aria-hidden="true" class="v-align-bottom" size="small" type="visibility"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 3a8.59 8.59 0 00-8 5 8.54 8.54 0 008 5 8.55 8.55 0 008-5 8.55 8.55 0 00-8-5zm0 8a3 3 0 113-3 3 3 0 01-3 3zm2-3a2 2 0 11-2-2 2 2 0 012 2z"></path>
#  </svg></li-icon><span class="white-space-pre"> </span>Solo para ti<!-- --></span><span class="visually-hidden"><li-icon aria-hidden="true" class="v-align-bottom" size="small" type="visibility"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 3a8.59 8.59 0 00-8 5 8.54 8.54 0 008 5 8.55 8.55 0 008-5 8.55 8.55 0 00-8-5zm0 8a3 3 0 113-3 3 3 0 01-3 3zm2-3a2 2 0 11-2-2 2 2 0 012 2z"></path>
#  </svg></li-icon><span class="white-space-pre"> </span>Solo para ti<!-- --></span>
#  </p>
#  </div>
#  <!-- --> </div>
#  <!-- --> </div>
#  </div>
#  <div>
#  <section class="pvs-carousel artdeco-carousel ember-view" id="ember95"><div class="artdeco-carousel__heading artdeco-carousel__heading--custom">
#  <div class="overflow-hidden ph4 pv3">
#  <!-- -->
#  </div>
#  <button aria-label="Ir al elemento anterior" class="artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--primary artdeco-button--disabled ember-view pvs-carousel__navigation-button artdeco-pagination__button--previous previous-btn" disabled="" id="ember96" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-rtl="true" data-supported-dps="16x16" data-test-icon="chevron-left-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#chevron-left-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#  </span></button>
#  <button aria-label="Ir al siguiente elemento" class="artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--primary artdeco-button--disabled ember-view pvs-carousel__navigation-button artdeco-pagination__button--next next-btn" disabled="" id="ember97" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-rtl="true" data-supported-dps="16x16" data-test-icon="chevron-right-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#chevron-right-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#  </span></button>
#  <!-- --></div>
#  <div class="artdeco-carousel__content">
#  <div class="overflow-hidden ph4 pv3">
#  <ul class="artdeco-carousel__slider ember-view" id="ember98" style="transform: translateX(0px);">
#  <li class="artdeco-carousel__item active ember-view" data-item-index="0" id="ember99" style="width: 604px; max-width: none; min-width: auto;" tabindex="-1"><div class="artdeco-carousel__item-container" data-test-display="display">
#  <div class="artdeco-card pv-profile-component-builder__card full-width display-flex flex-column">
#  <div class="p3 pr6 relative display-flex flex-column flex-grow-1">
#  <!-- --> <div class="pvs-prompt__title-container">
#  <div class="ivm-image-view-model mr2">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <svg aria-hidden="true" class="" data-supported-dps="48x48" data-test-icon="camera" height="48" role="none" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#  <!-- --> <svg display="var(--hue-web-svg-display-dark)">
#  <image height="48" href="https://static.licdn.com/aero-v1/sc/h/5ll5b061wxw7885977vlfaidv" width="48" x="0" y="0"/>
#  </svg>
#  <svg display="var(--hue-web-svg-display-light)">
#  <image height="48" href="https://static.licdn.com/aero-v1/sc/h/7lvc02mht78mhn2h6hk5ipiha" width="48" x="0" y="0"/>
#  </svg>
#  </svg>
#  </div>
#  </div>
#  <div>
#  <!-- --> <div>
#  <span class="m0 t-16 t-bold">
#  <span aria-hidden="true"><!-- -->Añade una foto de perfil para que te reconozcan.<!-- --></span><span class="visually-hidden"><!-- -->Añade una foto de perfil para que te reconozcan.<!-- --></span>
#  </span>
#  <!-- --> </div>
#  </div>
#  </div>
#  <div class="display-flex flex-column justify-space-between flex-grow-1">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center t-14">
#  <span aria-hidden="true"><!-- -->Los miembros que incluyen su foto reciben hasta 2,3 veces más visualizaciones del perfil.<!-- --></span><span class="visually-hidden"><!-- -->Los miembros que incluyen su foto reciben hasta 2,3 veces más visualizaciones del perfil.<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <div class="pvs-prompt__actions">
#  <!-- -->
#  <div class="pv-action pv-action__padding">
#  <div>
#  <a aria-hidden="false" class="optional-action-target-wrapper artdeco-button artdeco-button--secondary artdeco-button--standard artdeco-button--2 artdeco-button--muted inline-flex justify-center align-self-flex-start button-placement-wrap" href="https://www.linkedin.com/in/juan--ruiz/edit/photo/?legoTrackingId=..." id="navigation-photo-ge-add-photo" tabindex="0" target="_self">
#  <!-- --> <span class="pvs-navigation__text">
#                Añadir foto
#              </span>
#  <!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div></li>
#  <!-- --> </ul>
#  </div>
#  <button aria-label="Ir al elemento anterior" class="artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--primary artdeco-button--disabled ember-view pvs-carousel__navigation-button artdeco-pagination__button--previous previous-btn" disabled="" id="ember102" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-rtl="true" data-supported-dps="16x16" data-test-icon="chevron-left-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#chevron-left-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#  </span></button>
#  <button aria-label="Ir al siguiente elemento" class="artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--1 artdeco-button--primary artdeco-button--disabled ember-view pvs-carousel__navigation-button artdeco-pagination__button--next next-btn" disabled="" id="ember103" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-rtl="true" data-supported-dps="16x16" data-test-icon="chevron-right-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#chevron-right-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#  </span></button>
#  </div>
#  <!-- -->
#  <div aria-live="polite" class="visually-hidden" id="artdeco-carousel__a11y-notification"></div></section>
#  </div>
#  </section>,
#  <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="insights">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-large">
#  <span aria-hidden="true"><!-- -->Análisis<!-- --></span><span class="visually-hidden"><!-- -->Análisis<!-- --></span>
#  </h2>
#  <p class="aGTiVlXecKunGWGjpybvhxekCdZYfgnmmOrTm pvs-header__optional-link text-body-small">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><li-icon aria-hidden="true" class="v-align-bottom" size="small" type="visibility"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 3a8.59 8.59 0 00-8 5 8.54 8.54 0 008 5 8.55 8.55 0 008-5 8.55 8.55 0 00-8-5zm0 8a3 3 0 113-3 3 3 0 01-3 3zm2-3a2 2 0 11-2-2 2 2 0 012 2z"></path>
#  </svg></li-icon><span class="white-space-pre"> </span>Solo para ti<!-- --></span><span class="visually-hidden"><li-icon aria-hidden="true" class="v-align-bottom" size="small" type="visibility"><svg class="mercado-match" data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <path d="M8 3a8.59 8.59 0 00-8 5 8.54 8.54 0 008 5 8.55 8.55 0 008-5 8.55 8.55 0 00-8-5zm0 8a3 3 0 113-3 3 3 0 01-3 3zm2-3a2 2 0 11-2-2 2 2 0 012 2z"></path>
#  </svg></li-icon><span class="white-space-pre"> </span>Solo para ti<!-- --></span>
#  </p>
#  <!-- --> </div>
#  <!-- --> </div>
#  <!-- --> </div>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY ph5 display-flex flex-row flex-wrap">
#  <li class="pvs-list__item--three-column">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="insights_wvmp" href="https://www.linkedin.com/me/profile-views" tabindex="-1" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <li-icon aria-label="100 visualizaciones del perfil" class="ivm-view-attr__icon ivm-view-attr__icon--icon" role="img" size="large" type="people"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M12 16v6H3v-6a3 3 0 013-3h3a3 3 0 013 3zm5.5-3A3.5 3.5 0 1014 9.5a3.5 3.5 0 003.5 3.5zm1 2h-2a2.5 2.5 0 00-2.5 2.5V22h7v-4.5a2.5 2.5 0 00-2.5-2.5zM7.5 2A4.5 4.5 0 1012 6.5 4.49 4.49 0 007.5 2z"></path>
#  </svg></li-icon>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="insights_wvmp" href="https://www.linkedin.com/me/profile-views" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->100 visualizaciones del perfil<!-- --></span><span class="visually-hidden"><!-- -->100 visualizaciones del perfil<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Descubre quién ha visto tu perfil.<!-- --></span><span class="visually-hidden"><!-- -->Descubre quién ha visto tu perfil.<!-- --></span>
#  </span>
#  <!-- --><!-- --> </a>
#  </div>
#  <!-- --> </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="pvs-list__item--three-column">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="insights_content_impressions" href="https://www.linkedin.com/analytics/creator/content?timeRange=past_7_days&amp;dimension=INDUSTRY&amp;metricType=IMPRESSIONS" tabindex="-1" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <li-icon aria-label="0 impresiones de tu publicación" class="ivm-view-attr__icon ivm-view-attr__icon--icon" role="img" size="large" type="analytics"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M23 20v1H1v-1zM8 9H2v10h6zm7-6H9v16h6zm7 11h-6v5h6z"></path>
#  </svg></li-icon>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="insights_content_impressions" href="https://www.linkedin.com/analytics/creator/content?timeRange=past_7_days&amp;dimension=INDUSTRY&amp;metricType=IMPRESSIONS" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->0 impresiones de tu publicación<!-- --></span><span class="visually-hidden"><!-- -->0 impresiones de tu publicación<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Comienza una publicación para aumentar la interacción.<!-- --></span><span class="visually-hidden"><!-- -->Comienza una publicación para aumentar la interacción.<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->Últimos 7 días<!-- --></span><span class="visually-hidden"><!-- -->Últimos 7 días<!-- --></span>
#  </span>
#  <!-- --> </a>
#  </div>
#  <!-- --> </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="pvs-list__item--three-column">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="insights_search_appearances" href="https://www.linkedin.com/me/search-appearances/" tabindex="-1" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <li-icon aria-label="41 apariciones en búsquedas" class="ivm-view-attr__icon ivm-view-attr__icon--icon" role="img" size="large" type="search"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M21.41 18.59l-5.27-5.28A6.83 6.83 0 0017 10a7 7 0 10-7 7 6.83 6.83 0 003.31-.86l5.28 5.27a2 2 0 002.82-2.82zM5 10a5 5 0 115 5 5 5 0 01-5-5z"></path>
#  </svg></li-icon>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="insights_search_appearances" href="https://www.linkedin.com/me/search-appearances/" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->41 apariciones en búsquedas<!-- --></span><span class="visually-hidden"><!-- -->41 apariciones en búsquedas<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Mira con qué frecuencia apareces en los resultados de búsqueda.<!-- --></span><span class="visually-hidden"><!-- -->Mira con qué frecuencia apareces en los resultados de búsqueda.<!-- --></span>
#  </span>
#  <!-- --><!-- --> </a>
#  </div>
#  <!-- --> </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  </ul>
#  <div class="pvs-list__footer-wrapper">
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--2 artdeco-button--muted inline-flex justify-center full-width align-items-center artdeco-button--fluid" href="https://www.linkedin.com/dashboard" id="navigation-index-view-all-analytics" target="_self">
#  <!-- --> <span class="pvs-navigation__text">
#                Mostrar todos los análisis
#              </span>
#  <div class="pvs-navigation__icon">
#  <svg aria-hidden="true" data-rtl="true" data-supported-dps="16x16" data-test-icon="arrow-right-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#arrow-right-small" width="16"></use>
#  </svg>
#  </div>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- -->
#  </section>,
#  <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="about">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-large">
#  <span aria-hidden="true"><!-- -->Acerca de<!-- --></span><span class="visually-hidden"><!-- -->Acerca de<!-- --></span>
#  </h2>
#  <!-- --><!-- --> </div>
#  <!-- --> </div>
#  <div class="KdkRpsQpBenInYCGULBHNyAtPLTYbeUaw">
#  <!-- -->
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--3 artdeco-button--muted artdeco-button--circle inline-flex justify-center align-self-flex-start button-placement-wrap" href="https://www.linkedin.com/in/juan--ruiz/add-edit/SUMMARY/?profileFormEntryPoint=PROFILE_SECTION&amp;trackingId=X8dhBPZYQLCw%2FbUqQnyghw%3D%3D" id="navigation-add-edit-deeplink-edit-about" target="_self">
#  <div class="pvs-navigation__icon">
#  <svg aria-hidden="false" aria-label="Editar «Acerca de»" data-supported-dps="24x24" data-test-icon="edit-medium" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#edit-medium" width="24"></use>
#  </svg>
#  </div>
#  <!-- --><!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="display-flex ph5 pv3">
#  <div class="display-flex full-width" data-generated-suggestion-target="urn:li:fsu_profileActionDelegate:1140915470">
#  <div class="vAsWwauYZLnbIJTmqYdYAVomkinxqUhsFlSg full-width t-14 t-normal t-black display-flex align-items-center" dir="ltr">
#  <div class="hahogcWcORxLZJrdqEfouKXPCNpLTpzFsAIXc inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp full-width" dir="ltr" style="-webkit-line-clamp:4;" tabindex="-1">
#  <span aria-hidden="true"><!-- -->Confió plenamente en mis habilidades blandas para liderar y crear equipos de trabajos sólidos, basándome en la participación y escucha activa de todos los colaboradores.<!-- --><br/><br/><!-- -->Así como confesar ser un apasionado en la búsqueda de resolución de problemas, lo cual implica tener siempre una gran motivación para seguir perfeccionando habilidades que a futuro permitan desarrollar ideas/soluciones sólidas y duraderas.<!-- --></span><span class="visually-hidden"><!-- -->Confió plenamente en mis habilidades blandas para liderar y crear equipos de trabajos sólidos, basándome en la participación y escucha activa de todos los colaboradores.
#
#  Así como confesar ser un apasionado en la búsqueda de resolución de problemas, lo cual implica tener siempre una gran motivación para seguir perfeccionando habilidades que a futuro permitan desarrollar ideas/soluciones sólidas y duraderas.<!-- --></span>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --><!-- --><!-- --> </div>
#  </div>
#  </section>,
#  <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="content_collections">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-large">
#  <span aria-hidden="true"><!-- -->Actividad<!-- --></span><span class="visually-hidden"><!-- -->Actividad<!-- --></span>
#  </h2>
#  <p class="aGTiVlXecKunGWGjpybvhxekCdZYfgnmmOrTm pvs-header__optional-link text-body-small">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><a class="ZgsYcCdumgONIXFCFoqDwhJKByvjHoEAMMI" data-test-app-aware-link="" href="https://www.linkedin.com/feed/followers/" tabindex="0" target="_self"><strong><!-- -->2.673 seguidores<!-- --></strong></a></span><span class="visually-hidden"><a class="ZgsYcCdumgONIXFCFoqDwhJKByvjHoEAMMI" data-test-app-aware-link="" href="https://www.linkedin.com/feed/followers/" tabindex="0" target="_self"><strong><!-- -->2.673 seguidores<!-- --></strong></a></span>
#  </p>
#  <!-- --> </div>
#  <div class="pvs-header__primary-cta--with-button-spacing">
#  <div class="pv-action p2">
#  <div>
#  <a aria-hidden="false" class="optional-action-target-wrapper artdeco-button artdeco-button--secondary artdeco-button--standard artdeco-button--2 artdeco-button--default inline-flex justify-center align-self-flex-start button-placement-wrap" href="https://www.linkedin.com/in/juan--ruiz/overlay/create-post" id="navigation-create-post-Crear-una-publicaci-n" target="_self">
#  <!-- --> <span class="pvs-navigation__text">
#                Crear una publicación
#              </span>
#  <!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="KdkRpsQpBenInYCGULBHNyAtPLTYbeUaw">
#  <!-- -->
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" aria-label="Editar tipo de contenido predeterminado" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--3 artdeco-button--muted artdeco-button--circle inline-flex justify-center align-self-flex-start button-placement-wrap" href="https://www.linkedin.com/in/juan--ruiz/add-edit/CONTENT_COLLECTIONS_STAR_PILL/?profileFormEntryPoint=PROFILE_SECTION&amp;trackingId=IyIjVSp3RuCLiohBhIJJgw%3D%3D" id="navigation-add-edit-deeplink-edit-recent" target="_self">
#  <div class="pvs-navigation__icon">
#  <svg aria-hidden="true" data-supported-dps="24x24" data-test-icon="edit-medium" height="24" role="none" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#edit-medium" width="24"></use>
#  </svg>
#  </div>
#  <!-- --><!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="mb3">
#  <!-- -->
#  </div>
#  <div class="pv0 ph5">
#  <div class="display-flex flex-column full-width pb3">
#  <span class="text-body-medium-bold">Aún no has publicado nada</span>
#  <span class="text-body-small">Las publicaciones que compartas aparecerán aquí.</span>
#  </div>
#  </div>
#  <footer>
#  <a class="ZgsYcCdumgONIXFCFoqDwhJKByvjHoEAMMI profile-creator-shared-content-view__footer-action artdeco-button artdeco-button--muted artdeco-button--icon-right artdeco-button--3 artdeco-button--fluid artdeco-button--tertiary" data-test-app-aware-link="" href="https://www.linkedin.com/in/juan--ruiz/recent-activity/all/">
#  <svg aria-hidden="true" class="artdeco-button__icon" data-rtl="true" data-supported-dps="16x16" data-test-icon="arrow-right-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#arrow-right-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#              Mostrar toda la actividad
#            </span>
#  </a>
#  </footer>
#  <!-- -->
#  </section>,
#  <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="experience">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-large">
#  <span aria-hidden="true"><!-- -->Experiencia<!-- --></span><span class="visually-hidden"><!-- -->Experiencia<!-- --></span>
#  </h2>
#  <!-- --><!-- --> </div>
#  <!-- --> </div>
#  <div class="KdkRpsQpBenInYCGULBHNyAtPLTYbeUaw">
#  <div class="pv-action">
#  <div class="artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-right ember-view" id="ember116">
#  <button aria-expanded="false" class="artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--3 artdeco-button--tertiary artdeco-button-dropdown-trigger" id="overflow-Añadir-nueva-experiencia" tabindex="0" type="button">
#  <div class="ivm-image-view-model">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <li-icon aria-label="Añadir nueva experiencia" class="ivm-view-attr__icon" role="img" size="large" type="add"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M21 13h-8v8h-2v-8H3v-2h8V3h2v8h8z"></path>
#  </svg></li-icon>
#  </div>
#  </div>
#  <!-- --></button>
#  <div aria-hidden="true" class="artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view pvs-overflow-content--width" id="ember118" tabindex="-1"><!-- --></div>
#  </div>
#  <div class="ember-view" id="ember119"><div class="ember-view" id="ember120"><!-- --></div></div>
#  </div>
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--3 artdeco-button--muted artdeco-button--circle inline-flex justify-center align-self-flex-start button-placement-wrap" href="https://www.linkedin.com/in/juan--ruiz/details/experience?profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" id="navigation-index-edit-position" target="_self">
#  <div class="pvs-navigation__icon">
#  <svg aria-hidden="false" aria-label="Ver la pantalla detallada de experiencia" data-supported-dps="24x24" data-test-icon="edit-medium" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="24" href="#edit-medium" width="24"></use>
#  </svg>
#  </div>
#  <!-- --><!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <div class="pvs-entity__image-container--outline-offset display-flex" tabindex="-1">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <svg aria-hidden="false" aria-label="Cambio de profesión" class="" data-supported-dps="48x48" data-test-icon="calendar" height="48" role="img" viewbox="0 0 48 48" width="48" xmlns="http://www.w3.org/2000/svg">
#  <!-- --> <svg display="var(--hue-web-svg-display-dark)">
#  <image height="48" href="https://static.licdn.com/aero-v1/sc/h/2a4hjt62k9kbvuwu9rzg6ypgh" width="48" x="0" y="0"/>
#  </svg>
#  <svg display="var(--hue-web-svg-display-light)">
#  <image height="48" href="https://static.licdn.com/aero-v1/sc/h/p4pvtlgggtwlz9lht17nvnqq" width="48" x="0" y="0"/>
#  </svg>
#  </svg>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <div class="display-flex flex-column full-width">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 t-bold">
#  <span aria-hidden="true"><!-- -->Cambio de profesión<!-- --></span><span class="visually-hidden"><!-- -->Cambio de profesión<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Descanso profesional<!-- --></span><span class="visually-hidden"><!-- -->Descanso profesional<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->jul. 2024 - actualidad · 1 año<!-- --></span><span class="visually-hidden"><!-- -->jul. 2024 - actualidad · 1 año<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true"><!-- -->Buenos Aires<!-- --></span><span class="visually-hidden"><!-- -->Buenos Aires<!-- --></span>
#  </span>
#  </div>
#  </div>
#  <!-- --> </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="experience_company_logo" href="https://www.linkedin.com/company/5724/" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="Logotipo de Ball Corporation" class="ivm-view-attr__img--centered EntityPhoto-square-3 evi-image lazy-image ember-view" height="48" id="ember126" loading="lazy" src="https://media.licdn.com/dms/image/v2/D560BAQF12f1XsZ6jBw/company-logo_100_100/company-logo_100_100/0/1725484453578/ballcorporation_logo?e=1754524800&amp;v=beta&amp;t=v-bVkuHD3lAxFXBhrb6ZjNqSS0W0TiiRjahNcVIpnMo" width="48"/>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="experience_company_logo" href="https://www.linkedin.com/in/juan--ruiz/add-edit/POSITION/?profileFormEntryPoint=PROFILE_SECTION&amp;entityUrn=urn%3Ali%3Afsd_profilePosition%3A%28ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU%2C2636948508%29&amp;trackingId=K8WUOBi5R7KbRpnojxgxhA%3D%3D&amp;desktopBackground=MAIN_PROFILE" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->Production Chief<!-- --></span><span class="visually-hidden"><!-- -->Production Chief<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Ball Corporation · Jornada completa<!-- --></span><span class="visually-hidden"><!-- -->Ball Corporation · Jornada completa<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->jul. 2023 - jun. 2024 · 1 año<!-- --></span><span class="visually-hidden"><!-- -->jul. 2023 - jun. 2024 · 1 año<!-- --></span>
#  </span>
#  <!-- --> </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="pvs-list__item--with-top-padding ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="mv1 display-flex align-items-center">
#  <a class="optional-action-target-wrapper display-flex link-without-hover-visited" data-field="position_contextual_skills_see_details" href="https://www.linkedin.com/in/juan--ruiz/overlay/urn:li:fsd_profilePosition:(ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU,2636948508)/skill-associations-details?profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" target="_self">
#  <div class="mr1 mv1">
#  <ul class="ivm-entity-pile display-flex align-items-center t-black">
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <svg aria-hidden="true" class="ivm-view-attr__icon ivm-view-attr__icon--icon" data-supported-dps="16x16" data-test-icon="skills-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#skills-small" width="16"></use>
#  </svg>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="hoverable-link-text display-flex align-items-center t-14 t-normal t-black">
#  <strong><!-- -->Lean manufacturing, Resolución de problemas y 1 aptitud más<!-- --></strong>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  </a>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="experience_company_logo" href="https://www.linkedin.com/company/20078437/" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="Logotipo de Trivium Packaging" class="ivm-view-attr__img--centered EntityPhoto-square-3 evi-image lazy-image ember-view" height="48" id="ember132" loading="lazy" src="https://media.licdn.com/dms/image/v2/C560BAQFzB6Hk1vJs1A/company-logo_100_100/company-logo_100_100/0/1636449476992/trivium_packaging_logo?e=1754524800&amp;v=beta&amp;t=A77X8UdU7Oyj6M9wPTsDp-P_DgNthk8st7RKYP8GMs0" width="48"/>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="experience_company_logo" href="https://www.linkedin.com/in/juan--ruiz/add-edit/POSITION/?profileFormEntryPoint=PROFILE_SECTION&amp;entityUrn=urn%3Ali%3Afsd_profilePosition%3A%28ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU%2C2061437793%29&amp;trackingId=dAL7rUAoQaqfUqgjmzO%2Bmw%3D%3D&amp;desktopBackground=MAIN_PROFILE" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->Ingeniero de procesos y mejora continua<!-- --></span><span class="visually-hidden"><!-- -->Ingeniero de procesos y mejora continua<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Trivium Packaging · Jornada completa<!-- --></span><span class="visually-hidden"><!-- -->Trivium Packaging · Jornada completa<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->ago. 2022 - abr. 2023 · 9 meses<!-- --></span><span class="visually-hidden"><!-- -->ago. 2022 - abr. 2023 · 9 meses<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span><span class="visually-hidden"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span>
#  </span>
#  </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="pvs-list__item--with-top-padding ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="mv1 display-flex align-items-center">
#  <a class="optional-action-target-wrapper display-flex link-without-hover-visited" data-field="position_contextual_skills_see_details" href="https://www.linkedin.com/in/juan--ruiz/overlay/urn:li:fsd_profilePosition:(ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU,2061437793)/skill-associations-details?profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" target="_self">
#  <div class="mr1 mv1">
#  <ul class="ivm-entity-pile display-flex align-items-center t-black">
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <svg aria-hidden="true" class="ivm-view-attr__icon ivm-view-attr__icon--icon" data-supported-dps="16x16" data-test-icon="skills-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#skills-small" width="16"></use>
#  </svg>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="hoverable-link-text display-flex align-items-center t-14 t-normal t-black">
#  <strong><!-- -->Python, Microsoft SQL Server y 25 aptitudes más<!-- --></strong>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  </a>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="experience_company_logo" href="https://www.linkedin.com/company/1440481/" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="Logotipo de CAMBRE SA" class="ivm-view-attr__img--centered EntityPhoto-square-3 evi-image lazy-image ember-view" height="48" id="ember138" loading="lazy" src="https://media.licdn.com/dms/image/v2/C4E0BAQHt5lcKlWpH_A/company-logo_100_100/company-logo_100_100/0/1631300447328?e=1754524800&amp;v=beta&amp;t=LuphScxN7PhQcnDmmTYtUhq2KOinMyPeb3YiSZj8v_A" width="48"/>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="experience_company_logo" href="https://www.linkedin.com/in/juan--ruiz/add-edit/POSITION/?profileFormEntryPoint=PROFILE_SECTION&amp;entityUrn=urn%3Ali%3Afsd_profilePosition%3A%28ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU%2C1969810288%29&amp;trackingId=Ur3QddvXRd%2BA53Q32OZW%2FQ%3D%3D&amp;desktopBackground=MAIN_PROFILE" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->Jefe de Mantenimiento y mejora continua<!-- --></span><span class="visually-hidden"><!-- -->Jefe de Mantenimiento y mejora continua<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->CAMBRE SA · Jornada completa<!-- --></span><span class="visually-hidden"><!-- -->CAMBRE SA · Jornada completa<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->ene. 2021 - ago. 2022 · 1 año 8 meses<!-- --></span><span class="visually-hidden"><!-- -->ene. 2021 - ago. 2022 · 1 año 8 meses<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span><span class="visually-hidden"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span>
#  </span>
#  </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="pvs-list__item--with-top-padding ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="mv1 display-flex align-items-center">
#  <a class="optional-action-target-wrapper display-flex link-without-hover-visited" data-field="position_contextual_skills_see_details" href="https://www.linkedin.com/in/juan--ruiz/overlay/urn:li:fsd_profilePosition:(ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU,1969810288)/skill-associations-details?profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" target="_self">
#  <div class="mr1 mv1">
#  <ul class="ivm-entity-pile display-flex align-items-center t-black">
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <svg aria-hidden="true" class="ivm-view-attr__icon ivm-view-attr__icon--icon" data-supported-dps="16x16" data-test-icon="skills-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#skills-small" width="16"></use>
#  </svg>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="hoverable-link-text display-flex align-items-center t-14 t-normal t-black">
#  <strong><!-- -->Python, Modelado de datos y 28 aptitudes más<!-- --></strong>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  </a>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="experience_company_logo" href="https://www.linkedin.com/search/results/all/?keywords=Dielo+%28Fantoche%29" tabindex="-1" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <div class="EntityPhoto-square-3-ghost-company ivm-view-attr__ghost-entity">
#  <div class="visually-hidden">Dielo (Fantoche)</div>
#  </div>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="experience_company_logo" href="https://www.linkedin.com/search/results/all/?keywords=Dielo+%28Fantoche%29" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->Dielo (Fantoche)<!-- --></span><span class="visually-hidden"><!-- -->Dielo (Fantoche)<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <span class="t-14 t-normal">
#  <span aria-hidden="true"><!-- -->Jornada completa · 1 año 10 meses<!-- --></span><span class="visually-hidden"><!-- -->Jornada completa · 1 año 10 meses<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span><span class="visually-hidden"><!-- -->Provincia de Buenos Aires, Argentina<!-- --></span>
#  </span>
#  <!-- --> </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <span class="qhbLbUzsTBdsxGWEwqaDrBvFfBHbRhIdQ"></span>
#  <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT hMpGkrBQgkuMqEZIwswNsHKViOfFncOkPDHGUbdT" data-view-name="profile-component-entity">
#  <div>
#  <div class="display-flex" tabindex="-1">
#  <!-- -->
#  </div>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" href="https://www.linkedin.com/in/juan--ruiz/add-edit/POSITION/?profileFormEntryPoint=PROFILE_SECTION&amp;entityUrn=urn%3Ali%3Afsd_profilePosition%3A%28ACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU%2C2636949057%29&amp;trackingId=JrVuyl5qQHeaHhwfyYeRLw%3D%3D&amp;desktopBackground=MAIN_PROFILE" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true"><!-- -->Jefe de mantenimiento<!-- --></span><span class="visually-hidden"><!-- -->Jefe de mantenimiento<!-- --></span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <!-- --> <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->feb. 2020 - ene. 2021 · 1 año<!-- --></span><span class="visually-hidden"><!-- -->feb. 2020 - ene. 2021 · 1 año<!-- --></span>
#  </span>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true"><!-- -->Presencial<!-- --></span><span class="visually-hidden"><!-- -->Presencial<!-- --></span>
#  </span>
#  </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="pvs-list__item--with-top-padding ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="vAsWwauYZLnbIJTmqYdYAVomkinxqUhsFlSg full-width t-14 t-normal t-black display-flex align-items-center" dir="ltr">
#  <div class="hahogcWcORxLZJrdqEfouKXPCNpLTpzFsAIXc inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp full-width" dir="ltr" style="-webkit-line-clamp:2;" tabindex="-1">
# ...
#  <!-- -->
#  <use height="16" href="#verified-small" width="16"></use>
#  </svg>
#  </div>
#  </div>
#  <!-- --> </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="vAsWwauYZLnbIJTmqYdYAVomkinxqUhsFlSg full-width t-14 t-normal display-flex align-items-center" dir="ltr">
#  <div class="hahogcWcORxLZJrdqEfouKXPCNpLTpzFsAIXc inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp full-width" dir="ltr" style="-webkit-line-clamp:2;" tabindex="-1">
#  <span aria-hidden="true"><!-- -->Gerente Asistente de Producción Planta Argentina Ball Corporation<!-- --></span><span class="visually-hidden"><!-- -->Gerente Asistente de Producción Planta Argentina Ball Corporation<!-- --></span>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --> </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="pv-action pv-action__padding">
#  <button aria-label="Invita a Christian Tapia Lopez a conectar" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember389" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="16x16" data-test-icon="connect-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#connect-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#      Conectar
#  </span></button>
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  <!-- -->
#  </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  </ul>
#  <div class="pvs-list__footer-wrapper">
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" aria-label="Mostrar a todas las personas que podrías conocer" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--2 artdeco-button--muted inline-flex justify-center full-width align-items-center artdeco-button--fluid" href="https://www.linkedin.com/in/juan--ruiz/overlay/pymk-recommendations-from-company?isPrefetched=true&amp;profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" id="navigation-overlay-section-pymk-position-see-more-pymk-recommendations-from-company" target="_self">
#  <!-- --> <span class="pvs-navigation__text">
#                Mostrar todo
#              </span>
#  <!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- -->
#  </section>,
#  <section class="artdeco-card pv-profile-card break-words mt2" data-view-name="profile-card" tabindex="-1">
#  <!-- -->
#  <div class="pv-profile-card__anchor" id="company_recommendation">
#  </div>
#  <!-- -->
#  <!-- -->
#  <div class="BExDcfHshVeNBdsXYdAyKTUmkhChXtSsLwFY">
#  <div class="pvs-header__top-container--no-stack">
#  <div class="pvs-header__left-container--stack">
#  <div class="DRuOXUJpnucBINXZmXeGsjGaOqVlonfkHfPac">
#  <!-- --> <h2 class="pvs-header__title text-heading-medium">
#  <span aria-hidden="true"><!-- -->Podría gustarte<!-- --></span><span class="visually-hidden"><!-- -->Podría gustarte<!-- --></span>
#  </h2>
#  <p class="aGTiVlXecKunGWGjpybvhxekCdZYfgnmmOrTm pvs-header__optional-link text-body-small">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->Páginas para ti<!-- --></span><span class="visually-hidden"><!-- -->Páginas para ti<!-- --></span>
#  </p>
#  <!-- --> </div>
#  <!-- --> </div>
#  <!-- --> </div>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="company_card_click" href="https://www.linkedin.com/company/37143/" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="Logotipo de Banco Macro" class="ivm-view-attr__img--centered EntityPhoto-square-3 evi-image lazy-image ember-view" height="48" id="ember392" loading="lazy" src="https://media.licdn.com/dms/image/v2/D4D0BAQHi1gFO8umAtA/company-logo_100_100/B4DZbPGai1HsAQ-/0/1747231288229/bancomacro_logo?e=1754524800&amp;v=beta&amp;t=14yCtyEgECj6HiKhIxv76i_rZSnOkBdA7dfiniw7sOA" width="48"/>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="company_card_click" href="https://www.linkedin.com/company/37143/" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true">
#  <!-- -->Banco Macro<!-- -->
#  </span><span class="visually-hidden">
#  <!-- -->Banco Macro<!-- -->
#  </span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="vAsWwauYZLnbIJTmqYdYAVomkinxqUhsFlSg full-width t-14 t-normal display-flex align-items-center" dir="ltr">
#  <div class="hahogcWcORxLZJrdqEfouKXPCNpLTpzFsAIXc inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp full-width" dir="ltr" style="-webkit-line-clamp:2;" tabindex="-1">
#  <span aria-hidden="true"><!-- -->Banca<!-- --></span><span class="visually-hidden"><!-- -->Banca<!-- --></span>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->444.215 seguidores<!-- --></span><span class="visually-hidden"><!-- -->444.215 seguidores<!-- --></span>
#  </span>
#  <!-- --> </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="mv1 display-flex align-items-center">
#  <a class="optional-action-target-wrapper display-flex link-without-hover-visited" href="https://www.linkedin.com/company/37143/" target="_self">
#  <div class="mr2 mv1">
#  <ul class="ivm-entity-pile display-flex align-items-center t-black">
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember397" loading="lazy" src="https://media.licdn.com/dms/image/v2/D4E03AQFtAdkXVu0PLg/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1730394999227?e=1754524800&amp;v=beta&amp;t=VBj_ybXKGONTPNcw2UbVkI0WldBtZcsqsgWAflVAhAc" width="24"/>
#  </div>
#  </li>
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember398" loading="lazy" src="https://media.licdn.com/dms/image/v2/C4D03AQHro7lFxPlf0A/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1516972849637?e=1754524800&amp;v=beta&amp;t=35cYq411oyuHF_1wr30pE-b6stSERhqNPemXOQ5UvKg" width="24"/>
#  </div>
#  </li>
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember399" loading="lazy" src="https://media.licdn.com/dms/image/v2/C4D03AQEoWG9EOmrqYA/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1616762445628?e=1754524800&amp;v=beta&amp;t=Okpo3Ud7y6nFmnxrRb8OmVHlFy2WpGKfUtALG7MdWtA" width="24"/>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="hoverable-link-text display-flex align-items-center t-14 t-normal t-black">
#  <!-- -->653 contactos siguen esta página<!-- -->
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  </a>
#  <!-- --> </div>
#  </li>
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="pv-action pv-action__padding">
#  <button aria-label="Seguir a Banco Macro" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember401" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="16x16" data-test-icon="add-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#add-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#      Seguir
#  </span></button>
#  </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  <li class="artdeco-list__item UbyzeVyYlwqytFEFrQVYzimFKqwCsBVkUfaRkVgg ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <!-- --> <div class="GrJhtxcsKtuxnUWSKcaazdLPUdrqqT oTBKIVDbGtFmdUsZIRyNplDkmIHzxSvMrurg xnQvdPqNIUeCiCiENalkATAnmHlqErqMZvu" data-view-name="profile-component-entity">
#  <div>
#  <a class="optional-action-target-wrapper pvs-entity__image-container--outline-offset display-flex" data-field="company_card_click" href="https://www.linkedin.com/company/94153998/" target="_self">
#  <div class="ivm-image-view-model pvs-entity__image">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="Logotipo de BA Búsquedas GCBA" class="ivm-view-attr__img--centered EntityPhoto-square-3 evi-image lazy-image ember-view" height="48" id="ember403" loading="lazy" src="https://media.licdn.com/dms/image/v2/D4D0BAQEPVxW3Ic256g/company-logo_100_100/B4DZYbGo8aG8Ac-/0/1744211448856/babusquedas_gcba_logo?e=1754524800&amp;v=beta&amp;t=rxEFth5oihEBRBPOpwCrR460kFh1bbKyG414j9tEFzU" width="48"/>
#  </div>
#  </div>
#  </a>
#  </div>
#  <div class="display-flex flex-column align-self-center flex-grow-1">
#  <div class="display-flex flex-row justify-space-between">
#  <a class="optional-action-target-wrapper display-flex flex-column full-width" data-field="company_card_click" href="https://www.linkedin.com/company/94153998/" target="_self">
#  <div class="display-flex flex-wrap align-items-center full-height">
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="display-flex align-items-center mr1 hoverable-link-text t-bold">
#  <span aria-hidden="true">
#  <!-- -->BA Búsquedas GCBA<!-- -->
#  </span><span class="visually-hidden">
#  <!-- -->BA Búsquedas GCBA<!-- -->
#  </span>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <!-- --><!-- --><!-- --> </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="vAsWwauYZLnbIJTmqYdYAVomkinxqUhsFlSg full-width t-14 t-normal display-flex align-items-center" dir="ltr">
#  <div class="hahogcWcORxLZJrdqEfouKXPCNpLTpzFsAIXc inline-show-more-text--is-collapsed inline-show-more-text--is-collapsed-with-line-clamp full-width" dir="ltr" style="-webkit-line-clamp:2;" tabindex="-1">
#  <span aria-hidden="true"><!-- -->Administración pública<!-- --></span><span class="visually-hidden"><!-- -->Administración pública<!-- --></span>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  <span class="t-14 t-normal t-black--light">
#  <span aria-hidden="true" class="pvs-entity__caption-wrapper"><!-- -->66.225 seguidores<!-- --></span><span class="visually-hidden"><!-- -->66.225 seguidores<!-- --></span>
#  </span>
#  <!-- --> </a>
#  </div>
#  <div class="xrcAJlbWDEMobIZjCuhUwpEiDVASQqqyvWg pvs-entity__sub-components">
#  <!-- --> <ul class="lNIBNAfxAaBMIZuMVwQswPzNTtybDHkY">
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="mv1 display-flex align-items-center">
#  <a class="optional-action-target-wrapper display-flex link-without-hover-visited" href="https://www.linkedin.com/company/94153998/" target="_self">
#  <div class="mr2 mv1">
#  <ul class="ivm-entity-pile display-flex align-items-center t-black">
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember408" loading="lazy" src="https://media.licdn.com/dms/image/v2/D4E03AQFtAdkXVu0PLg/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1730394999227?e=1754524800&amp;v=beta&amp;t=VBj_ybXKGONTPNcw2UbVkI0WldBtZcsqsgWAflVAhAc" width="24"/>
#  </div>
#  </li>
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember409" loading="lazy" src="https://media.licdn.com/dms/image/v2/C4D03AQEoWG9EOmrqYA/profile-displayphoto-shrink_100_100/profile-displayphoto-shrink_100_100/0/1616762445628?e=1754524800&amp;v=beta&amp;t=Okpo3Ud7y6nFmnxrRb8OmVHlFy2WpGKfUtALG7MdWtA" width="24"/>
#  </div>
#  </li>
#  <li class="ivm-entity-pile__img-item--stacked">
#  <div class="ivm-view-attr__img-wrapper">
#  <!-- -->
#  <!-- --> <img alt="" class="ivm-view-attr__img--centered ivm-view-attr__img--stacked ivm-view-attr__img--stacked-circle-size-0 EntityPhoto-circle-0-stackedFacepile evi-image lazy-image ember-view" height="24" id="ember410" loading="lazy" src="https://media.licdn.com/dms/image/v2/D4D35AQEtxwo6vXgE8Q/profile-framedphoto-shrink_100_100/B4DZYAwVI0H4Ak-/0/1743769392020?e=1749348000&amp;v=beta&amp;t=NUgXXmEOiPUOl7TRaaltYK8CyTIHVTDvT31N6cCO5pM" width="24"/>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="display-flex">
#  <div class="display-flex full-width">
#  <div class="hoverable-link-text display-flex align-items-center t-14 t-normal t-black">
#  <!-- -->158 contactos siguen esta página<!-- -->
#  </div>
#  <!-- -->
#  </div>
#  </div>
#  </a>
#  <!-- --> </div>
#  </li>
#  <li class="ssMIyLwSPDLDdRyGzqMKVhAvPZTRrMizznw">
#  <div class="pv-action pv-action__padding">
#  <button aria-label="Seguir a BA Búsquedas GCBA" class="artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember412" type="button"> <svg aria-hidden="true" class="artdeco-button__icon" data-supported-dps="16x16" data-test-icon="add-small" height="16" role="none" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#  <!-- -->
#  <use height="16" href="#add-small" width="16"></use>
#  </svg>
#  <span class="artdeco-button__text">
#      Seguir
#  </span></button>
#  </div>
#  </li>
#  </ul>
#  <!-- --> </div>
#  </div>
#  <!-- -->
#  <!-- --> </div>
#  </li>
#  </ul>
#  <div class="pvs-list__footer-wrapper">
#  <div class="pv-action">
#  <div>
#  <a aria-hidden="false" aria-label="Mostrar todo lo que te podría gustar" class="optional-action-target-wrapper artdeco-button artdeco-button--tertiary artdeco-button--standard artdeco-button--2 artdeco-button--muted inline-flex justify-center full-width align-items-center artdeco-button--fluid" href="https://www.linkedin.com/in/juan--ruiz/overlay/company-recommendations?isPrefetched=true&amp;profileUrn=urn%3Ali%3Afsd_profile%3AACoAADK01BwBbnspBrU1S3_JqTVRoi3kfPStbpU" id="navigation-overlay-section-see-more-company-recommendations" target="_self">
#  <!-- --> <span class="pvs-navigation__text">
#                Mostrar todo
#              </span>
#  <!-- --> </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <!-- -->
#  </section>]
